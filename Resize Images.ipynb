# %%
import cv2
import os

# %%
images = os.listdir('/home/ghost/Downloads/fifty')

# %%
images
# Out:
# ['07201.jpg',
#  '21601.jpg',
#  '44001.jpg',
#  '107601.jpg',
#  '43201.jpg',
#  '16801.jpg',
#  '118001.jpg',
#  '166801.jpg',
#  '72001.jpg',
#  '26401.jpg',
#  '79201.jpg',
#  '108001.jpg',
#  '24801.jpg',
#  '106401.jpg',
#  '116401.jpg',
#  '10001.jpg',
#  '142001.jpg',
#  '100401.jpg',
#  '70001.jpg',
#  '114801.jpg',
#  '96001.jpg',
#  '30401.jpg',
#  '12001.jpg',
#  '65201.jpg',
#  '84001.jpg',
#  '142801.jpg',
#  '118801.jpg',
#  '65601.jpg',
#  '11201.jpg',
#  '100801.jpg',
#  '35601.jpg',
#  '104801.jpg',
#  '119201.jpg',
#  '17601.jpg',
#  '91201.jpg',
#  '117601.jpg',
#  '28401.jpg',
#  '20001.jpg',
#  '90801.jpg',
#  '19601.jpg',
#  '71601.jpg',
#  '120001.jpg',
#  '127601.jpg',
#  '122801.jpg',
#  '46401.jpg',
#  '159201.jpg',
#  '70401.jpg',
#  '82001.jpg',
#  '39601.jpg',
#  '112801.jpg',
#  '54401.jpg',
#  '34001.jpg',
#  '12401.jpg',
#  '117201.jpg',
#  '84401.jpg',
#  '20401.jpg',
#  '36001.jpg',
#  '76001.jpg',
#  '11601.jpg',
#  '09201.jpg',
#  '83201.jpg',
# ...

# %%
for file in images:
    im = cv2.imread('/home/ghost/Downloads/fifty/'+file)
    resized_im = im.resize((150,100))
    cv2.imwrite(file,resized_im)
